# %%
from scipy.misc import derivative

import matplotlib.pyplot as plt


# Посчитаем значение первой и второй производной функции
def f(x):
    return x**5 + 4*np.sin(2*x) + np.cos(3*x+x)

print("Первая производная функции в точке x=1 - ", derivative(f,1.0,dx=1e-6, n=1))
print("Вторая производная функции в точке x=1 - ", derivative(f,1.0,dx=1e-6, n=2))

# Построим график первой и второй производной функции
def F(x):
    return (np.sin(2*x+1))**5

X = np.linspace(-5,5)

fun_first_derivative = [derivative(F,xx,dx=1e-6, n=1) for xx in X]
fun_second_derivative = [derivative(F,xx,dx=1e-6, n=2) for xx in X]

plt.plot(x, fun_first_derivative, label = 'first_derivative')
plt.plot(x, fun_second_derivative, label = 'second_derivative')
plt.grid()
plt.show()
# Out:
# Первая производная функции в точке x=1 -  4.698035288575042
# Вторая производная функции в точке x=1 -  15.909495942878493
